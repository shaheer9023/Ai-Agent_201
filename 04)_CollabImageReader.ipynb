# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheer9023/Ai-Agent_201/blob/main/04)_CollabImageReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
key=userdata.get('2.O_exp')

# %%
if key:
  print("key found")
else:
  print("key not found")
# Out:
# key found

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=key)
model=genai.GenerativeModel("gemini-2.0-flash-exp")

# %%
from google.colab import files
from PIL import Image
import io

# 📂 Image upload karne ka button show karo
uploaded = files.upload()

# 📸 Pehli uploaded image ka naam le lo
if uploaded:
    file_name = list(uploaded.keys())[0]

    # 🖼 Image ko open aur show karo
    image = Image.open(file_name)
    image.show()
    print(f"Image uploaded successfully: {file_name}")
else:
    print("No file selected!")
# Out:
#      <input type="file" id="files-77757c45-9ecb-469a-9290-0ff17ad41ccb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77757c45-9ecb-469a-9290-0ff17ad41ccb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
prompt=input("enter prompt : ")
response=model.generate_content([prompt,image])
from IPython.display import Markdown
Markdown(response.text)

# %%
import requests
from PIL import Image
from io import BytesIO

url="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXhRArOnqaaKwR2lM8V7MV0po2qrcryAdABg&s"
response=requests.get(url)
image=Image.open(BytesIO(response.content))
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x159>

# %%
prompt=input("enter prompt : ")
response=model.generate_content([prompt,image])
from IPython.display import Markdown
Markdown(response.text)
# Out:
# enter prompt : explain given image
# The image showcases a picturesque landscape featuring a prominent mountain and a cascading waterfall. The mountain, likely Kirkjufell in Iceland, dominates the scene with its distinctive cone-like shape and grassy green slopes. The sun appears to be rising or setting, casting a warm glow on the mountaintop.
#
# In the foreground, a tiered waterfall rushes into a dark, rocky river. The water is captured with a slightly blurred effect, giving it a sense of motion and softness. Patches of green grass and moss add texture to the riverbanks.
#
# The sky above is a mix of blues and oranges, suggesting either sunrise or sunset. Clouds are scattered across the sky, adding depth to the overall composition. The horizon line includes a glimpse of water or a bay, further enhancing the sense of expansive landscape. The photograph captures a beautiful and iconic scene, highlighting the natural beauty of the area.
